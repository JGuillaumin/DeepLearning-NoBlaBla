# %% [markdown]
# # Préparation des données :
#
#     - Convertir en noir et blanc
#     - Mettre sour la forme d'un vecteur 32x32
#     - récupérer les labels sous forme d'entier

# %%
import glob
import re
from scipy import misc
import pandas as  pd
import numpy as np

from sklearn.model_selection import train_test_split
import cPickle as pickle 

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
labels_dict = {'airplane':0,
               'automobile':1, 
               'bird':2,
               'cat':3,
               'deer':4,
               'dog':5,
               'frog':6,
               'horse':7,
               'ship':8, 
               'truck':9}

# %% [markdown]
# ### Pour les données d'entrainement

# %% [markdown]
# #### Exemple pour une image

# %%
image_path = 'train/9967.png'

# %%
img_color = misc.imread(image_path)
print img_color.shape
plt.imshow(img_color)
# Out:
# (32, 32, 3)

# %%
img = misc.imread(image_path,mode='L')
print img.shape
plt.imshow(img,cmap='gray')
# Out:
# (32, 32)

# %%
img_resize = img.reshape((32*32,))
print img_resize.shape
# Out:
# (1024,)

# %% [markdown]
# ### Retrouver le label ?

# %%
# !ls
# Out:
# preparation_donnees.ipynb  test   train.pkl
# sampleSubmission.csv	   train  trainLabels.csv

# %%
df = pd.read_csv('trainLabels.csv', sep=',', skiprows=0)

# %%
df.head()
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
image_path
# Out:
# 'train/9967.png'

# %%
id_image  = re.findall(r'\d+', image_path)[0]
print id_image
# Out:
# 9967

# %%
label = df.get_value(int(id_image) - 1,'label')
print label
# Out:
# airplane

# %%
encoded_label = labels_dict[label]
print encoded_label
# Out:
# 0

# %% [markdown]
# ### On reprend tout

# %%
path = 'train/*.png'
files = glob.glob(path)

# %%
print len(files)
files[:5]
# Out:
# 50000
# ['train/9967.png',
#  'train/9968.png',
#  'train/9969.png',
#  'train/997.png',
#  'train/9970.png']

# %%
X = []
y = []

df = pd.read_csv('trainLabels.csv', sep=',', skiprows=0)

for i,file in enumerate(files):
    img = misc.imread(file,mode='L')
    img = img.reshape((32*32,))
    
    X.append(img)
    
    id_image  = re.findall(r'\d+', file)[0]
    label = df.get_value(int(id_image) - 1,'label')
    
    y.append(labels_dict[label])
    
    if (i+1)%10000==0:
        print i
# Out:
# 9999
# 19999
# 29999
# 39999
# 49999

# %%
X = np.asarray(X, dtype='float32')
y = np.asarray(y, dtype='int8')

print X.shape
print y.shape
# Out:
# (50000, 1024)
# (50000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42, stratify=y)

# %%
print X_train.shape
print X_test.shape
# Out:
# (42500, 1024)
# (7500, 1024)

# %%
pickle.dump((X_train, X_test, y_train, y_test),open("train.pkl","w"))
