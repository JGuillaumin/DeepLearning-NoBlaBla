# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

from IPython.display import Image as Image_Jupyter
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Les données : Cats vs Dogs (kaggle)

# %%
train_dogs = '../data/cats-dogs/train_resize/dogs/'
train_cats = '../data/cats-dogs/train_resize/cats/'

test = '../data/cats-dogs/test_resize/'

# %%
import PIL
from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = Image.open('../data/cats-dogs/train_resize/cats/10.jpg')
plt.imshow(img)

# %%
ROWS = 100
COLS = 100

# %% [markdown]
# # Modèle : AlexNet (2012)

# %%
Image_Jupyter(filename='../ressources/alexnet.png')

# %% [markdown]
#  - Dropout (régularisation)
#  - Cropping (augmentation de données)
#  - ReLU (fonction d'activation)
#
# ## Caisse à outils :

# %%
# Point de départ
from keras.models import Sequential

# Couches nécessaires
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Convolution2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D

# Régularisation ? 
from keras.regularizers import l2

# Algorithme d'optimisation 
from keras.optimizers import SGD, RMSprop
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

model.add(Convolution2D(96, 11, 11,subsample=(2,2), border_mode='same', input_shape=(ROWS, COLS,3), activation='relu'))
# batch normalization ? 
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2),border_mode='valid'))
model.add(Convolution2D(384, 5, 5,subsample=(1,1), border_mode='same', activation='relu'))
# batch normalization ? 
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2),border_mode='valid'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(384, 3, 3, border_mode='same', activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(384, 3, 3, border_mode='same', activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, 3, 3, border_mode='same', activation='relu'))
model.add(MaxPooling2D((3, 3), strides=(2,2), border_mode='valid'))


model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
    
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_1 (Convolution2D)  (None, 50, 50, 96)    34944       convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 25, 25, 96)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 25, 25, 384)   921984      maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 12, 12, 384)   0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_1 (ZeroPadding2D)  (None, 14, 14, 384)   0           maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 14, 14, 384)   1327488     zeropadding2d_1[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_2 (ZeroPadding2D)  (None, 16, 16, 384)   0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 16, 16, 384)   1327488     zeropadding2d_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_3 (ZeroPadding2D)  (None, 18, 18, 384)   0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 18, 18, 256)   884992      zeropadding2d_3[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)    (None, 8, 8, 256)     0           convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 16384)         0           maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1024)          16778240    flatten_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 1024)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 1024)          1049600     dropout_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 1024)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 1)             1025        dropout_2[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 1)             0           dense_3[0][0]
# ====================================================================================================
# Total params: 22,325,761
# Trainable params: 22,325,761
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
sgd = SGD(lr=0.01)
rms = RMSprop(lr=0.0001)
model.compile(loss='binary_crossentropy', optimizer=rms, metrics=['accuracy'])

# %% [markdown]
# # Gérer un gros dataset avec Keras
#
# - Lorsqu'il est impossible de tout charger en mémoire

# %%
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# - générateur de batch
# - augmentation de données en temps réel
#
#
#
# ```python
# keras.preprocessing.image.ImageDataGenerator(featurewise_center=False,
#     samplewise_center=False,
#     featurewise_std_normalization=False,
#     samplewise_std_normalization=False,
#     zca_whitening=False,
#     rotation_range=0.,
#     width_shift_range=0.,
#     height_shift_range=0.,
#     shear_range=0.,
#     zoom_range=0.,
#     channel_shift_range=0.,
#     fill_mode='nearest',
#     cval=0.,
#     horizontal_flip=False,
#     vertical_flip=False,
#     rescale=None,
#     dim_ordering=K.image_dim_ordering())
#
# ```
#
# Permet aussi de manipuler des gros dataset :
# - une classe par répertoire
# - augmentation de données et resize en temps réel

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        rotation_range=20.0)

train_generator = train_datagen.flow_from_directory(
        '../data/cats-dogs/train_resize/',
        target_size=(100, 100),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 25000 images belonging to 2 classes.

# %%
model.fit_generator(
        train_generator,
        samples_per_epoch=25000,
        nb_epoch=50,
        verbose=1)
# Out:
# Epoch 1/50
#   256/25000 [..............................] - ETA: 1274s - loss: 0.7000 - acc: 0.4883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-66ed29fda0b1> in <module>()
#       3         samples_per_epoch=25000,
#       4         nb_epoch=50,
# ----> 5         verbose=1)
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/models.py in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch, **kwargs)
#     933                                         nb_worker=nb_worker,
#     934                                         pickle_safe=pickle_safe,
# --> 935                                         initial_epoch=initial_epoch)
#     936
#     937     def evaluate_generator(self, generator, val_samples,
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch)
#    1516                     outs = self.train_on_batch(x, y,
#    1517                                                sample_weight=sample_weight,
# -> 1518                                                class_weight=class_weight)
#    1519                 except:
#    1520                     _stop.set()
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1275             ins = x + y + sample_weights
#    1276         self._make_train_function()
# -> 1277         outputs = self.train_function(ins)
#    1278         if len(outputs) == 1:
#    1279             return outputs[0]
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    1888         session = get_session()
#    1889         updated = session.run(self.outputs + [self.updates_op],
# -> 1890                               feed_dict=feed_dict)
#    1891         return updated[:len(self.outputs)]
#    1892
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# !ls
# Out:
# ALEXNET-CORRECTION.ipynb  model_0.76.h5

# %%
model.load_weights('model_0.76.h5')

# %%
model.fit_generator(
        train_generator,
        samples_per_epoch=25000,
        nb_epoch=50,
        verbose=1)
# Out:
# Epoch 1/50
# 25000/25000 [==============================] - 739s - loss: 0.4435 - acc: 0.7940
# Epoch 2/50
# 14080/25000 [===============>..............] - ETA: 329s - loss: 0.4087 - acc: 0.8166
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-66ed29fda0b1> in <module>()
#       3         samples_per_epoch=25000,
#       4         nb_epoch=50,
# ----> 5         verbose=1)
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/models.py in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch, **kwargs)
#     933                                         nb_worker=nb_worker,
#     934                                         pickle_safe=pickle_safe,
# --> 935                                         initial_epoch=initial_epoch)
#     936
#     937     def evaluate_generator(self, generator, val_samples,
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch)
#    1516                     outs = self.train_on_batch(x, y,
#    1517                                                sample_weight=sample_weight,
# -> 1518                                                class_weight=class_weight)
#    1519                 except:
#    1520                     _stop.set()
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1275             ins = x + y + sample_weights
#    1276         self._make_train_function()
# -> 1277         outputs = self.train_function(ins)
#    1278         if len(outputs) == 1:
#    1279             return outputs[0]
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    1888         session = get_session()
#    1889         updated = session.run(self.outputs + [self.updates_op],
# -> 1890                               feed_dict=feed_dict)
#    1891         return updated[:len(self.outputs)]
#    1892
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model.save_weights('model_0.81.h5')

# %%
model.load_weights('model_0.81.h5')

# %%
from quiver_engine import server

# %%
server.launch(model, classes=['cat','dog'], input_folder='../data/cats-dogs/test_resize/', port=7000)
# Out:
# Starting webserver from: /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/quiver_engine
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET / HTTP/1.1" 200 802 0.006505
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /app.c1d3d21cfba8c1aabed6806773c8f0ba.css HTTP/1.1" 200 5131 0.001501
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /vendor.280c5ce1d78077ee8d66.js HTTP/1.1" 200 87557 0.002247
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /app.14b8092d6ea379715007.js HTTP/1.1" 200 1179471 0.008182
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /model HTTP/1.1" 200 6799 0.003624
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /inputs HTTP/1.1" 200 1221 0.001729
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /favicon.ico HTTP/1.1" 200 16181 0.001108
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /input-file/0.jpg HTTP/1.1" 200 3605 0.002804
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /input-file/5.jpg HTTP/1.1" 200 3299 0.002186
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:16] "GET /input-file
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/52.jpg HTTP/1.1" 200 3281 0.001824
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/54.jpg HTTP/1.1" 200 3806 0.001705
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/60.jpg HTTP/1.1" 200 4026 0.001703
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/53.jpg HTTP/1.1" 200 3358 0.001214
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/56.jpg HTTP/1.1" 200 3113 0.001563
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/57.jpg HTTP/1.1" 200 4683 0.001930
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/59.jpg HTTP/1.1" 200 3836 0.001781
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/7.jpg HTTP/1.1" 200 4234 0.001568
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/70.jpg HTTP/1.1" 200 3285 0.001657
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/73.jpg HTTP/1.1" 200 2582 0.002322
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/58.jpg HTTP/1.1" 200 2852 0.002004
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/62.jpg HTTP/1.1" 200 3013 0.001784
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/77.jpg HTTP/1.1" 200 4503 0.001783
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/63.jpg HTTP/1.1" 200 3196 0.001666
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/65.jpg HTTP/1.1" 200 3295 0.002049
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/66.jpg HTTP/1.1" 200 3450 0.002257
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/74.jpg HTTP/1.1" 200 3626 0.002529
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/72.jpg HTTP/1.1" 200 3397 0.001174
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/76.jpg HTTP/1.1" 200 3933 0.001668
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/78.jpg HTTP/1.1" 200 3051 0.001616
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/80.jpg HTTP/1.1" 200 3080 0.002785
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/8.jpg HTTP/1.1" 200 3106 0.003500
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:17] "GET /input-file/9.jpg HTTP/1.1" 200 3098 0.003246
# [2017-01-17 20:07:26,158] ERROR in app: Exception on /predict/0.jpg [GET]
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/flask/app.py", line 1988, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/flask/app.py", line 1641, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/flask_cors/extension.py", line 161, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/flask/app.py", line 1544, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/flask/_compat.py", line 33, in reraise
#     raise value
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/flask/app.py", line 1639, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/flask/app.py", line 1625, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/quiver_engine/server.py", line 135, in get_prediction
#     model.predict(input_img), classes, top
#   File "/root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/quiver_engine/server.py", line 181, in decode_predictions
#     preds.shape[1], len(classes)))
# ValueError: you need to provide same number of classes as model prediction output model returns 1 predictions, while there are 2 classes
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /predict/0.jpg HTTP/1.1" 500 478 0.189393
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /layer/convolution2d_1/0.jpg HTTP/1.1" 200 3528 0.170142
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_0_0.jpg.png HTTP/1.1" 200 1861 0.002264
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_1_0.jpg.png HTTP/1.1" 200 2128 0.001668
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_2_0.jpg.png HTTP/1.1" 200 1978 0.001695
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_6_0.jpg.png HTTP/1.1" 200 1608 0.001800
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_5_0.jpg.png HTTP/1.1" 200 1433 0.002023
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_4_0.jpg.png HTTP/1.1" 200 2300 0.001672
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_3_0.jpg.png HTTP/1.1" 200 1707 0.002126
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_7_0.jpg.png HTTP/1.1" 200 2059 0.001662
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_11_0.jpg.png HTTP/1.1" 200 1933 0.001776
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_14_0.jpg.png HTTP/1.1" 200 2137 0.002036
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_15_0.jpg.png HTTP/1.1" 200 2065 0.001467
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_16_0.jpg.png HTTP/1.1" 200 1469 0.002107
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_10_0.jpg.png HTTP/1.1" 200 1663 0.001725
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_9_0.jpg.png HTTP/1.1" 200 2059 0.001960
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_8_0.jpg.png HTTP/1.1" 200 1971 0.001607
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_18_0.jpg.png HTTP/1.1" 200 1970 0.001523
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_19_0.jpg.png HTTP/1.1" 200 1535 0.001317
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_13_0.jpg.png HTTP/1.1" 200 2008 0.001474
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1_20_0.jpg.png HTTP/1.1" 200 2161 0.001507
# ::ffff:172.17.0.1 - - [2017-01-17 20:07:26] "GET /temp-file/convolution2d_1
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_362_12.jpg.png HTTP/1.1" 200 501 0.001163
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_363_12.jpg.png HTTP/1.1" 200 567 0.001130
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_364_12.jpg.png HTTP/1.1" 200 394 0.001279
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_365_12.jpg.png HTTP/1.1" 200 564 0.001626
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_367_12.jpg.png HTTP/1.1" 200 487 0.001629
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_368_12.jpg.png HTTP/1.1" 200 467 0.001758
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_366_12.jpg.png HTTP/1.1" 200 378 0.001774
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_369_12.jpg.png HTTP/1.1" 200 480 0.001475
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_370_12.jpg.png HTTP/1.1" 200 381 0.001721
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_371_12.jpg.png HTTP/1.1" 200 367 0.001219
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_372_12.jpg.png HTTP/1.1" 200 508 0.001180
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_373_12.jpg.png HTTP/1.1" 200 511 0.001351
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_376_12.jpg.png HTTP/1.1" 200 389 0.001143
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_374_12.jpg.png HTTP/1.1" 200 536 0.002173
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_375_12.jpg.png HTTP/1.1" 200 495 0.001733
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_377_12.jpg.png HTTP/1.1" 200 466 0.001283
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_378_12.jpg.png HTTP/1.1" 200 371 0.001187
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_380_12.jpg.png HTTP/1.1" 200 381 0.001116
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_381_12.jpg.png HTTP/1.1" 200 525 0.000998
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_379_12.jpg.png HTTP/1.1" 200 367 0.001063
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_382_12.jpg.png HTTP/1.1" 200 406 0.000987
# ::ffff:172.17.0.1 - - [2017-01-17 20:10:40] "GET /temp-file/convolution2d_3_383_12.jpg.png HTTP/1.1" 200 374 0.001362
# KeyboardInterrupt
# Tue Jan 17 20:53:25 2017
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-abea4db12672> in <module>()
# ----> 1 server.launch(model, classes=['cat','dog'], input_folder='../data/cats-dogs/test_resize/', port=7000)
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/quiver_engine/server.py in launch(model, classes, top, temp_folder, input_folder, port, html_base_dir)
#     163         get_app(model, classes, top, html_base_dir=html_base_dir,
#     164                 temp_folder=temp_folder, input_folder=input_folder),
# --> 165         port
#     166     )
#     167
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/quiver_engine/server.py in run_app(app, port)
#     145     http_server = WSGIServer(('', port), app)
#     146     webbrowser.open_new('http://localhost:' + str(port))
# --> 147     http_server.serve_forever()
#     148
#     149
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/gevent/baseserver.py in serve_forever(self, stop_timeout)
#     360             self.start()
#     361         try:
# --> 362             self._stop_event.wait()
#     363         finally:
#     364             Greenlet.spawn(self.stop, timeout=stop_timeout).join()
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/gevent/event.py in wait(self, timeout)
#     217             noticeable when the *timeout* is present.
#     218         """
# --> 219         return self._wait(timeout)
#     220
#     221     def _reset_internal_locks(self): # pragma: no cover
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/gevent/event.py in _wait(self, timeout)
#     127             return self._wait_return_value(False, False)
#     128
# --> 129         gotit = self._wait_core(timeout)
#     130         return self._wait_return_value(True, gotit)
#     131
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/gevent/event.py in _wait_core(self, timeout, catch)
#     104             try:
#     105                 try:
# --> 106                     result = self.hub.switch()
#     107                     if result is not self: # pragma: no cover
#     108                         raise InvalidSwitchError('Invalid switch into Event.wait(): %r' % (result, ))
#
# /root/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/gevent/hub.py in switch(self)
#     628         if switch_out is not None:
#     629             switch_out()
# --> 630         return RawGreenlet.switch(self)
#     631
#     632     def switch_out(self):
#
# KeyboardInterrupt:
